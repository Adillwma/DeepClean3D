# %%
import os
import matplotlib.pyplot as plt 
import numpy as np

#%% - User Inputs
time_dimension = 1000
dataset_full_filepath = r"N:\Yr 3 Project Datasets\TORCHSIM_Data\Dataset\Data" #r"N:\Yr 3 Project Datasets\Dataset 20_3_X5000\Data" #r"N:\Yr 3 Project Datasets\PDT 1000 FAST\Data"

# load some files form the dataset directory provided and show them along with thier titles 
dataset_files = os.listdir(dataset_full_filepath)
dataset_files.sort()


"""
print("Files in dataset directory: ")
for i, file in enumerate(dataset_files):
    print(f"{i+1}. {file}")
    # plot file
    plt.figure()
    plt.imshow(np.load(dataset_full_filepath + "/" + file))
    plt.title(file)
    plt.show()
"""

# select the files to be used for the comparison
file_1 = dataset_files[26]
dataset_1 = dataset_full_filepath
plt.figure()
plt.imshow(np.load(dataset_full_filepath + "/" + file_1))
plt.title(file_1)
plt.show()

# %%
# select the files to be used for the comparison
file_1 = dataset_files[17]
dataset_1 = dataset_full_filepath
plt.figure()
plt.imshow(np.load(dataset_full_filepath + "/" + file_1))
#plt.title(file_1)
plt.show()

print("Dataset:", dataset_1)
# Out:
# Dataset: N:\Yr 3 Project Datasets\TORCHSIM_Data\Dataset\Data

# %%
# select the files to be used for the comparison

plt.figure()
plt.imshow(np.load(dataset_full_filepath + "/" + file_2))
#plt.title(file_2)
plt.show()

print("Dataset:", dataset_2)
# Out:
# Dataset: N:\Yr 3 Project Datasets\Dataset 20_3_X5000\Data

# %%
# select the files to be used for the comparison

plt.figure()
plt.imshow(np.load(dataset_full_filepath + "/" + file_3))
#plt.title(file_3)
plt.show()

print("Dataset:", dataset_3)
# Out:
# Dataset: N:\Yr 3 Project Datasets\Realistic Data Testing\Data

# %%
# select the files to be used for the comparison

plt.figure()
plt.imshow(np.load(dataset_full_filepath + "/" + file_4))
plt.title(file_4)
plt.show()

print("Dataset:", dataset_4)
# Out:
# Dataset: N:\Yr 3 Project Datasets\PDT 1000 FAST\Data
